# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("walmart Project.xlsx")
data
# Out:
#      Sr_No                                       Product_Name      Brand_Name  \
# 0        1  Instant Pot Duo 6-Quart 7-in-1 Electric Pressu...     Instant Pot
# 1        2  The Pioneer Woman Sweet Romance 6-Quart Instan...         Pioneer
# 2        3  Instant Pot 6 Quart Duo Crisp Air Fryer 9-in-1...     Instant Pot
# 3        4  Denali Canning 23 Quart Pressure Canner Alumin...          Denali
# 4        5  Farberware 6-Quart Aluminum Stovetop Pressure ...      Farberware
# ..     ...                                                ...             ...
# 520    521  Hawkins Stainless Steel 2.0 Litre Pressure Cooker         Hawkins
# 521    522                      Presto 09903  Pressure Cooker         Presto
# 522    523        Grandest Birch Trump Design Pressure Cooker  Grandest Birch
# 523    524  Hawkins B21 Classic Aluminum Pressure Cooker w...         Hawkins
# 524    525      The Pioneer Woman Instant Pot Pressure Cooker     The Pioneer
#
# ...

# %%
data.shape
# Out:
# (525, 7)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=525, step=1)

# %%
data.columns
# Out:
# Index(['Sr_No', 'Product_Name', 'Brand_Name', 'Product_Price',
#        'Product_Reviews', 'Product_Rating', 'Shipping_Details'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sr_No             525 non-null    int64
#  1   Product_Name      525 non-null    object
#  2   Brand_Name        525 non-null    object
#  3   Product_Price     525 non-null    object
#  4   Product_Reviews   525 non-null    int64
#  5   Product_Rating    525 non-null    object
#  6   Shipping_Details  524 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 28.8+ KB

# %%
data.head()
# Out:
#    Sr_No                                       Product_Name   Brand_Name  \
# 0      1  Instant Pot Duo 6-Quart 7-in-1 Electric Pressu...  Instant Pot
# 1      2  The Pioneer Woman Sweet Romance 6-Quart Instan...      Pioneer
# 2      3  Instant Pot 6 Quart Duo Crisp Air Fryer 9-in-1...  Instant Pot
# 3      4  Denali Canning 23 Quart Pressure Canner Alumin...       Denali
# 4      5  Farberware 6-Quart Aluminum Stovetop Pressure ...   Farberware
#
#   Product_Price  Product_Reviews      Product_Rating Shipping_Details
# 0        $50.00             2645  4.7 our of 5 Stars           Pickup
# 1        $85.32              272  4.8 out of 5 Stars  3+ day shipping
# 2        $99.00               25  4.2 out of 5 Stars  3+ day shipping
# 3       $104.00                4    4 out of 5 Stars  3+ day shipping
# 4       $157.77              107    4 out of 5 Stars           Pickup

# %%
data.tail()
# Out:
#      Sr_No                                       Product_Name      Brand_Name  \
# 520    521  Hawkins Stainless Steel 2.0 Litre Pressure Cooker         Hawkins
# 521    522                      Presto 09903  Pressure Cooker         Presto
# 522    523        Grandest Birch Trump Design Pressure Cooker  Grandest Birch
# 523    524  Hawkins B21 Classic Aluminum Pressure Cooker w...         Hawkins
# 524    525      The Pioneer Woman Instant Pot Pressure Cooker     The Pioneer
#
#     Product_Price  Product_Reviews      Product_Rating Shipping_Details
# 520        $65.00                2    1 out of 5 Stars  3+ day shipping
# 521        $18.32                2    5 out of 5 Stars  3+ day shipping
# 522         $4.49               20  4.5 out of 5 Stars  3+ day shipping
# 523        $62.33               20  4.5 out of 5 Stars  3+ day shipping
# 524        $69.00             1880  4.7 out of 5 Stars  3+ day shipping

# %%
data.describe()
# Out:
#             Sr_No  Product_Reviews
# count  525.000000       525.000000
# mean   263.000000        65.977143
# std    151.698715       233.032636
# min      1.000000         1.000000
# 25%    132.000000         4.000000
# 50%    263.000000        20.000000
# 75%    394.000000        20.000000
# max    525.000000      2645.000000

# %%
data.isnull().sum()    # finding null values
# Out:
# Sr_No               0
# Product_Name        0
# Brand_Name          0
# Product_Price       0
# Product_Reviews     0
# Product_Rating      0
# Shipping_Details    1
# dtype: int64

# %%
data["Product_Price"].value_counts()
# Out:
# $99.00     13
# $104.00    13
# $14.99     13
# $85.32     12
# $157.77    12
#            ..
# $40.74      1
# $64.95      1
# $141.80     1
# $118.84     1
# $62.33      1
# Name: Product_Price, Length: 328, dtype: int64

# %%
sort1=data.sort_values(["Product_Price"],ascending="false")
sort1
# Out:
#      Sr_No                                       Product_Name  \
# 492    493  Steam Release Valve Universal Durable Electric...
# 444    445  2 Pk, Presto Pressure Cooker Overpressure Plug...
# 458    459  2-Pack 11-Inch Pressure Cooker Canner Rack/Can...
# 463    464  Universal Replacement Floater and Sealer for P...
# 312    313  Wilmington Steelwares Silicone Trivet, Fits 6,...
# ..     ...                                                ...
# 114    115  Refurbished Instant Pot Viva Black Multi-Use 9...
# 158    159                Hawkins M37 Contura Pressure Cooker
# 86      87    Barton 22-Quart Canner Aluminum Pressure Cooker
# 95      96  Farberware 8-Quart 7-in-1 Programmable Pressur...
# 246    247  Vinod V-10L Stainless Steel Sandwich Bottom Pr...
#
#                          Brand_Name Product_Price  Product_Reviews  \
# 492                   Steam Melease        $10.19               20
# 444                     2 Pk Mresto        $10.29                2
# ...

# %%
data.sort_values(['Product_Name'],ascending=False)[['Product_Price','Product_Name']].max()          # Pressure Cooker Name with Highest Price
# Out:
# Product_Price                                               $99.99
# Product_Name     Zimtown Stainless Steel 6QT Electric Pressure ...
# dtype: object

# %%
data.sort_values(['Product_Price'],ascending=True)[['Product_Price','Product_Name']].head(1)      # Pressure Cooker Name with Lowest Price
# Out:
#     Product_Price                                       Product_Name
# 492        $10.19  Steam Release Valve Universal Durable Electric...

# %%
data.sort_values(['Product_Name'],ascending=True)[['Product_Rating','Product_Name']].max()         # Highest rating for pressure cooker
# Out:
# Product_Rating                                     5 out of 5 Stars
# Product_Name      Zimtown Stainless Steel 6QT Electric Pressure ...
# dtype: object

# %%
data.sort_values(['Product_Name'],ascending=True)[['Product_Rating','Product_Name','Product_Price']].min()         # Lowest rating for pressure cooker
# Out:
# Product_Rating                                     1 out of 5 Stars
# Product_Name      "Happyline" 14 Pcs Instant Pot Accessories Set...
# Product_Price                                                $10.19
# dtype: object

# %%
data.sort_values(['Product_Name'],ascending=True)[['Product_Reviews','Product_Name']].max()         # Highest review for pressure cooker
# Out:
# Product_Reviews                                                 2645
# Product_Name       Zimtown Stainless Steel 6QT Electric Pressure ...
# dtype: object

# %%
data['Brand_Name'].min()           # Least buying product from customer
# Out:
# '"Bilot Mrecise'

# %%
data['Brand_Name'].max()            # Most buying product from customer
# Out:
# 'Zimtown Mtainless'

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 520    False
# 521    False
# 522    False
# 523    False
# 524    False
# Length: 525, dtype: bool

# %%
data.drop_duplicates()
# Out:
#      Sr_No                                       Product_Name  \
# 0        1  Instant Pot Duo 6-Quart 7-in-1 Electric Pressu...
# 1        2  The Pioneer Woman Sweet Romance 6-Quart Instan...
# 2        3  Instant Pot 6 Quart Duo Crisp Air Fryer 9-in-1...
# 3        4  Denali Canning 23 Quart Pressure Canner Alumin...
# 4        5  Farberware 6-Quart Aluminum Stovetop Pressure ...
# ..     ...                                                ...
# 520    521  Hawkins Stainless Steel 2.0 Litre Pressure Cooker
# 521    522  Presto 09903  Pressure Cooker Sealing Ring/Ove...
# 522    523  Grandest Birch Trump Design Pressure Cooker In...
# 523    524  Hawkins B21 Classic Aluminum Pressure Cooker w...
# 524    525  The Pioneer Woman Instant Pot LUX60 6 Qt 6-in-...
#
#                             Brand_Name Product_Price  Product_Reviews  \
# 0                          Instant Pot        $50.00             2645
# 1                              Pioneer        $85.32              272
# ...

# %%
data.groupby('Product_Name').Brand_Name.count()
# Out:
# Product_Name
# "Happyline" 14 Pcs Instant Pot Accessories Set,Pressure Cooker          1
# 09902, Pressure Cooker Sealing Ring Gasket For 6 Qt Fits Presto         1
# 09903, Pressure Cooker Sealing Gasket Ring Fits Presto 01/PE3 Models    1
# 09905, Pressure Cooker Sealing Ring Gasket Fits Presto                  1
# 09907, Pressure Cooker Sealing Ring Gasket Fits Presto                  1
#                                                                        ..
# Zavor ZPot Pressure Cooker                                              1
# Zimtown 1000W 6QT Stainless Steel Electric Pressure Cooker              1
# Zimtown 6QT 13 in 1 Cooking Mode Electric Pressure Cooker               1
# Zimtown 6QT Stainless Steel Electric Pressure Cooker                    1
# Zimtown Stainless Steel 6QT Electric Pressure Cooker                    1
# Name: Brand_Name, Length: 420, dtype: int64
